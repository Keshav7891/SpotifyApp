# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
SPOTIPY_CLIENT_ID='e18fafeb60a949d2a9b7d1efccabe69a'
SPOTIPY_CLIENT_SECRET='739bbbed49864382a64a64ccd64ecdcc'

# %%
auth_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
#  # Searching Tracks

# %%
results = sp.search(q='track:'+'shape',type='track')

# %%
items_in_tracks = results['tracks']['items']
if len(items_in_tracks) > 0:
    for item in items_in_tracks:
        print(item['name'] + " - By - " + item['artists'][0]['name'])
        print("Track ID: " + item['id'] + " / Artist ID - " + item['artists'][0]['id'])
        print("------")
# Out:
# Heart-Shaped Box - By - Nirvana
# Track ID: 11LmqTE2naFULdEP94AUBa / Artist ID - 6olE6TJLqED3rqDCT0FyPh
# ------
# Shape of You - By - Ed Sheeran
# Track ID: 7qiZfU4dY1lWllzX7mPBI3 / Artist ID - 6eUKZXaKkcviH0Ku9w2n3V
# ------
# Shape of My Heart - By - Backstreet Boys
# Track ID: 35o9a4iAfLl5jRmqMX9c1D / Artist ID - 5rSXSAkZ67PYJSvpUpkOr7
# ------
# Shape Of A Dream - By - Sailors Of The 7 Seas
# Track ID: 7M7YsLJWsyu87my5ZnAxau / Artist ID - 64u292UVi3Zlu0Dl9svsMb
# ------
# Shape of You - By - Ed Sheeran
# Track ID: 0FE9t6xYkqWXU2ahLh6D8X / Artist ID - 6eUKZXaKkcviH0Ku9w2n3V
# ------
# Shape Of My Heart - By - Sting
# Track ID: 6CKoWCWAqEVWVjpeoJXyNH / Artist ID - 0Ty63ceoRnnJKVEYP0VQpk
# ------
# Shapeshifting - By - Taylor Acorn
# Track ID: 2u3HTlrmGMP9jQv17o6UCz / Artist ID - 1A0WloDoRE88uUwo3wensY
# ------
# Shapes of Solitude - By - Astron
# Track ID: 679ajBE0hA1KXeV4ksYifn / Artist ID - 6qiuwoB9ro3SX0ZjSXnr0y
# ------
# Shapeshifter - By - Alessia Cara
# Track ID: 4pwD08Ptz19F3cqZasynVq / Artist ID - 2wUjUUtkb5lvLKcGKsKqsR
# ------
# Shapeshifter - By - Alessia Cara
# Track ID: 31bh49ZMeIoq3eySECXakm / Artist ID - 2wUjUUtkb5lvLKcGKsKqsR
# ------

# %%
song_id = '37Nqx7iavZpotJSDXZWbJ3'

# %% [markdown]
# # Generating token for recommendation

# %%
import requests
import base64

# %%
def get_token(clientId,clientSecret):
    url = "https://accounts.spotify.com/api/token"
    headers = {}
    data = {}
    message = f"{clientId}:{clientSecret}"
    messageBytes = message.encode('ascii')
    base64Bytes = base64.b64encode(messageBytes)
    base64Message = base64Bytes.decode('ascii')
    headers['Authorization'] = "Basic " + base64Message
    data['grant_type'] = "client_credentials"
    r = requests.post(url, headers=headers, data=data)
    token = r.json()['access_token']
    return token

# %%
token = get_token(SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET)

# %%
token
# Out:
# 'BQB68NKXsYw71FLGcQtTpEPyVZS8HaIQ-krK96z0f3Xsl2V0kYfKUvT73KfVLsjZjzt1gp7B13cBxYGOJsQRvGUcXuHNiRbvVWiS5u4xDeisahZO98Y'

# %% [markdown]
# # Getting recommendation based on song

# %%
def get_track_recommendations(seed_tracks,token):
    limit = 10
    recUrl = f"https://api.spotify.com/v1/recommendations?limit={limit}&seed_tracks={seed_tracks}"

    headers = {
        "Authorization": "Bearer " + token
    }

    res = requests.get(url=recUrl, headers=headers)
    return res.json()

# %%
json_response = get_track_recommendations(song_id,token)

# %%
uris =[]
for i in json_response['tracks']:
    uris.append(i)
    print(f"\"{i['name']}\" by({i['artists'][0]['name']})")
# Out:
# "first order of business" by(Baby Keem)
# "No Friends In The Industry" by(Drake)
# "Find A Way (feat. Lil Baby & Lil Durk)" by(H.E.R.)
# "Memories" by(dvsn)
# "Calling My Phone" by(Lil Tjay)
# "Chosen (feat. Ty Dolla $ign)" by(Blxst)
# "Drunk And Nasty (feat. Sharc)" by(Pi’erre Bourne)
# "Drama (feat. Drake)" by(Roy Woods)
# "Solid (feat. Drake)" by(Young Stoner Life)
# "Break from Toronto" by(PARTYNEXTDOOR)

# %%
#creating data frame of the recommendations
import pandas as pd

# %%
recolist = json_response['tracks']
recommendation_result = pd.DataFrame(recolist)
recommendation_result
# Out:
#                                                album  \
# 0  {'album_type': 'ALBUM', 'artists': [{'external...
# 1  {'album_type': 'ALBUM', 'artists': [{'external...
# 2  {'album_type': 'SINGLE', 'artists': [{'externa...
# 3  {'album_type': 'ALBUM', 'artists': [{'external...
# 4  {'album_type': 'ALBUM', 'artists': [{'external...
# 5  {'album_type': 'ALBUM', 'artists': [{'external...
# 6  {'album_type': 'ALBUM', 'artists': [{'external...
# 7  {'album_type': 'SINGLE', 'artists': [{'externa...
# 8  {'album_type': 'ALBUM', 'artists': [{'external...
# 9  {'album_type': 'ALBUM', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
# 5  [{'external_urls': {'spotify': 'https://open.s...
# 6  [{'external_urls': {'spotify': 'https://open.s...
# 7  [{'external_urls': {'spotify': 'https://open.s...
# 8  [{'external_urls': {'spotify': 'https://open.s...
# 9  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 5  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 6  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 8  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 9  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#    duration_ms  explicit              external_ids  \
# 0       168758      True  {'isrc': 'USSM12106869'}
# 1       204346      True  {'isrc': 'USUG12104408'}
# 2       212520      True  {'isrc': 'USRC12102375'}
# 3       164565      True  {'isrc': 'USWB12102675'}
# 4       205458      True  {'isrc': 'USSM12100388'}
# 5       161684      True  {'isrc': 'USP6L2000552'}
# 6       299970      True  {'isrc': 'USUM72109088'}
# 7       251859      True  {'isrc': 'USWB11508706'}
# 8       215693      True  {'isrc': 'QMCE32100237'}
# 9        99213      True  {'isrc': 'USWB11302160'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/4d...
# 1  {'spotify': 'https://open.spotify.com/track/2t...
# 2  {'spotify': 'https://open.spotify.com/track/4y...
# 3  {'spotify': 'https://open.spotify.com/track/5s...
# 4  {'spotify': 'https://open.spotify.com/track/3J...
# 5  {'spotify': 'https://open.spotify.com/track/1d...
# 6  {'spotify': 'https://open.spotify.com/track/1l...
# 7  {'spotify': 'https://open.spotify.com/track/0P...
# 8  {'spotify': 'https://open.spotify.com/track/6r...
# 9  {'spotify': 'https://open.spotify.com/track/79...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/4d6z0mKVcnhE...  4d6z0mKVcnhE5x0YWvTexh
# 1  https://api.spotify.com/v1/tracks/2tUL6dZf1myw...  2tUL6dZf1mywCj5WvCPZw6
# 2  https://api.spotify.com/v1/tracks/4yIH4PcUVivc...  4yIH4PcUVivcxNTy1ETMZ3
# 3  https://api.spotify.com/v1/tracks/5szyU7UOFTE4...  5szyU7UOFTE4lupMjbjbJj
# 4  https://api.spotify.com/v1/tracks/3J8EOeKLTLXO...  3J8EOeKLTLXORtWPpOU5bE
# 5  https://api.spotify.com/v1/tracks/1dIWPXMX4kRH...  1dIWPXMX4kRHj6Dt2DStUQ
# 6  https://api.spotify.com/v1/tracks/1lAJUXyP5S2d...  1lAJUXyP5S2dUYHer1xBas
# 7  https://api.spotify.com/v1/tracks/0PXp9QxBfSKG...  0PXp9QxBfSKGGpWUNaws2X
# 8  https://api.spotify.com/v1/tracks/6rTInqW3YECM...  6rTInqW3YECMkQsBEHw4sd
# 9  https://api.spotify.com/v1/tracks/79MSEdtXuudh...  79MSEdtXuudhGhC5AtG07g
#
#    is_local                                    name  popularity  \
# 0     False                 first order of business          66
# 1     False              No Friends In The Industry          74
# 2     False  Find A Way (feat. Lil Baby & Lil Durk)          56
# 3     False                                Memories          48
# 4     False                        Calling My Phone          81
# 5     False            Chosen (feat. Ty Dolla $ign)          78
# 6     False           Drunk And Nasty (feat. Sharc)          72
# 7     False                     Drama (feat. Drake)          75
# 8     False                     Solid (feat. Drake)          75
# 9     False                      Break from Toronto          81
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/d37d288907c53cf0...            14  track
# 1                                               None            12  track
# 2  https://p.scdn.co/mp3-preview/e7f6e2e389bb3e58...             1  track
# 3  https://p.scdn.co/mp3-preview/7bd8216804f4286d...             1  track
# 4  https://p.scdn.co/mp3-preview/379d1239f67ceb2b...             3  track
# 5  https://p.scdn.co/mp3-preview/232a5618e07b0721...            12  track
# 6                                               None            12  track
# 7  https://p.scdn.co/mp3-preview/5914b2a36eb2fe7c...             5  track
# 8  https://p.scdn.co/mp3-preview/368cfd7e10f4fb65...             4  track
# 9  https://p.scdn.co/mp3-preview/71e5ea959b3655d9...             6  track
#
#                                     uri
# 0  spotify:track:4d6z0mKVcnhE5x0YWvTexh
# 1  spotify:track:2tUL6dZf1mywCj5WvCPZw6
# 2  spotify:track:4yIH4PcUVivcxNTy1ETMZ3
# 3  spotify:track:5szyU7UOFTE4lupMjbjbJj
# 4  spotify:track:3J8EOeKLTLXORtWPpOU5bE
# 5  spotify:track:1dIWPXMX4kRHj6Dt2DStUQ
# 6  spotify:track:1lAJUXyP5S2dUYHer1xBas
# 7  spotify:track:0PXp9QxBfSKGGpWUNaws2X
# 8  spotify:track:6rTInqW3YECMkQsBEHw4sd
# 9  spotify:track:79MSEdtXuudhGhC5AtG07g
